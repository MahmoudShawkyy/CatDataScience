# %%
import pandas as pd

# %%
candy=pd.read_csv(r'/home/shawkyy/Downloads/candyhierarchy2017.csv')

# %%
candy.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %%
candy['Unnamed: 113']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2455    NaN
# 2456    NaN
# 2457    NaN
# 2458    NaN
# 2459    NaN
# Name: Unnamed: 113, Length: 2460, dtype: object

# %%
candy=candy.drop(['Unnamed: 113'],axis=1)

# %%
candy.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0     90258773            NaN        NaN     NaN         NaN
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                              NaN                NaN
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 0                                                NaN
# 1                                            DESPAIR
# 2                                                NaN
# ...

# %%
candy.isnull()
# Out:
#       Internal ID  Q1: GOING OUT?  Q2: GENDER  Q3: AGE  Q4: COUNTRY  \
# 0           False            True        True     True         True
# 1           False           False       False    False        False
# 2           False            True       False    False        False
# 3           False           False       False    False        False
# 4           False           False       False    False        False
# ...           ...             ...         ...      ...          ...
# 2455        False           False       False    False        False
# 2456        False           False       False    False        False
# 2457        False           False       False    False        False
# 2458        False           False       False    False        False
# 2459        False           False       False    False        False
#
#       Q5: STATE, PROVINCE, COUNTY, ETC  Q6 | 100 Grand Bar  \
# 0                                 True                True
# ...

# %%
candy.groupby('Q1: GOING OUT?').count()
# Out:
#                 Internal ID  Q2: GENDER  Q3: AGE  Q4: COUNTRY  \
# Q1: GOING OUT?
# No                     2038        2025     1990         2008
# Yes                     312         311      303          305
#
#                 Q5: STATE, PROVINCE, COUNTY, ETC  Q6 | 100 Grand Bar  \
# Q1: GOING OUT?
# No                                          1975                1422
# Yes                                          301                 230
#
#                 Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Q1: GOING OUT?
# No                                                           1440
# Yes                                                           228
#
#                 Q6 | Any full-sized candy bar  Q6 | Black Jacks  \
# Q1: GOING OUT?
# No                                       1486              1244
# Yes                                       239               203
#
#                 Q6 | Bonkers (the candy)  ...  Q7: JOY OTHER  \
# ...

# %%
candy.drop([0])
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 1        90272821             No       Male      44        USA
# 2        90272829            NaN       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# 5        90272852             No       Male     NaN         NaN
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1                                  NM                MEH
# 2                            Virginia                NaN
# ...

# %%
candy.groupby('Q2: GENDER').count()
# Out:
#                     Internal ID  Q1: GOING OUT?  Q3: AGE  Q4: COUNTRY  \
# Q2: GENDER
# Female                      839             825      828          835
# I'd rather not say           83              78       71           73
# Male                       1467            1404     1440         1449
# Other                        30              29       30           30
#
#                     Q5: STATE, PROVINCE, COUNTY, ETC  Q6 | 100 Grand Bar  \
# Q2: GENDER
# Female                                           826                 583
# I'd rather not say                                72                  60
# Male                                            1426                1041
# Other                                             29                  22
#
#                     Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Q2: GENDER
# Female                                                            591
# ...

# %%
candy.fillna(0)
# Out:
#       Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 0        90258773              0          0       0           0
# 1        90272821             No       Male      44        USA
# 2        90272829              0       Male      49         USA
# 3        90272840             No       Male      40          us
# 4        90272841             No       Male      23         usa
# ...           ...            ...        ...     ...         ...
# 2455     90314359             No       Male      24         USA
# 2456     90314580             No     Female      33         USA
# 2457     90314634             No     Female      26        USA
# 2458     90314658             No       Male      58         Usa
# 2459     90314802             No     Female      66         usa
#
#      Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 0                                   0                  0
# 1                                  NM                MEH
# ...

# %%
candy=candy.drop([0])

# %%
candy.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 1     90272821             No       Male      44        USA
# 2     90272829            NaN       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
# 5     90272852             No       Male     NaN         NaN
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1                               NM                MEH
# 2                         Virginia                NaN
# 3                               or                MEH
# 4                         exton pa                JOY
# 5                              NaN                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                            DESPAIR
# 2                                                NaN
# 3                                            DESPAIR
# ...

# %%
candy=candy.fillna(0)

# %%
candy.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 1     90272821             No       Male      44        USA
# 2     90272829              0       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
# 5     90272852             No       Male       0           0
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 1                               NM                MEH
# 2                         Virginia                  0
# 3                               or                MEH
# 4                         exton pa                JOY
# 5                                0                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 1                                            DESPAIR
# 2                                                  0
# 3                                            DESPAIR
# ...

# %%
candy=candy.drop([1])

# %%
#candy['Q3: AGE']=candy['Q3: AGE'].astype('int')

# %%
candy.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 2     90272829              0       Male      49         USA
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
# 5     90272852             No       Male       0           0
# 6     90272853             No       Male      53         usa
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 2                         Virginia                  0
# 3                               or                MEH
# 4                         exton pa                JOY
# 5                                0                JOY
# 6                        Colorado                   0
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 2                                                  0
# 3                                            DESPAIR
# 4                                            DESPAIR
# ...

# %%
candy=candy.drop([2])

# %%
candy.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
# 5     90272852             No       Male       0           0
# 6     90272853             No       Male      53         usa
# 7     90272854             No       Male      33      canada
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 3                               or                MEH
# 4                         exton pa                JOY
# 5                                0                JOY
# 6                        Colorado                   0
# 7                          ontario                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                            DESPAIR
# ...

# %%
candy=candy.drop([6])

# %%
candy.groupby('Q12: MEDIA [Yahoo]').count()
# Out:
#                     Internal ID  Q1: GOING OUT?  Q2: GENDER  Q3: AGE  \
# Q12: MEDIA [Yahoo]
# 0.0                        2389            2389        2389     2389
# 1.0                          67              67          67       67
#
#                     Q4: COUNTRY  Q5: STATE, PROVINCE, COUNTY, ETC  \
# Q12: MEDIA [Yahoo]
# 0.0                        2389                              2389
# 1.0                          67                                67
#
#                     Q6 | 100 Grand Bar  \
# Q12: MEDIA [Yahoo]
# 0.0                               2389
# 1.0                                 67
#
#                     Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Q12: MEDIA [Yahoo]
# 0.0                                                              2389
# 1.0                                                                67
#
#                     Q6 | Any full-sized candy bar  Q6 | Black Jacks  ...  \
# ...

# %%
candy=candy.drop(['Q12: MEDIA [Yahoo]'],axis=1)

# %%
candy.groupby('Q12: MEDIA [ESPN]').count()
# Out:
#                    Internal ID  Q1: GOING OUT?  Q2: GENDER  Q3: AGE  \
# Q12: MEDIA [ESPN]
# 0.0                       2357            2357        2357     2357
# 1.0                         99              99          99       99
#
#                    Q4: COUNTRY  Q5: STATE, PROVINCE, COUNTY, ETC  \
# Q12: MEDIA [ESPN]
# 0.0                       2357                              2357
# 1.0                         99                                99
#
#                    Q6 | 100 Grand Bar  \
# Q12: MEDIA [ESPN]
# 0.0                              2357
# 1.0                                99
#
#                    Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Q12: MEDIA [ESPN]
# 0.0                                                             2357
# 1.0                                                               99
#
#                    Q6 | Any full-sized candy bar  Q6 | Black Jacks  ...  \
# ...

# %%
candy=candy.drop(['Q12: MEDIA [ESPN]'],axis=1)

# %%
candy.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
# 5     90272852             No       Male       0           0
# 7     90272854             No       Male      33      canada
# 8     90272858             No       Male      40      Canada
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 3                               or                MEH
# 4                         exton pa                JOY
# 5                                0                JOY
# 7                          ontario                JOY
# 8                          Ontario                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                            DESPAIR
# ...

# %%
candy.groupby('Q12: MEDIA [Daily Dish]').count()
# Out:
#                          Internal ID  Q1: GOING OUT?  Q2: GENDER  Q3: AGE  \
# Q12: MEDIA [Daily Dish]
# 0.0                             2371            2371        2371     2371
# 1.0                               85              85          85       85
#
#                          Q4: COUNTRY  Q5: STATE, PROVINCE, COUNTY, ETC  \
# Q12: MEDIA [Daily Dish]
# 0.0                             2371                              2371
# 1.0                               85                                85
#
#                          Q6 | 100 Grand Bar  \
# Q12: MEDIA [Daily Dish]
# 0.0                                    2371
# 1.0                                      85
#
#                          Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# Q12: MEDIA [Daily Dish]
# 0.0                                                                   2371
# 1.0                                                                     85
#
# ...

# %%
candy=candy.drop(['Q12: MEDIA [Daily Dish]'],axis=1)

# %%
candy.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER Q3: AGE Q4: COUNTRY  \
# 3     90272840             No       Male      40          us
# 4     90272841             No       Male      23         usa
# 5     90272852             No       Male       0           0
# 7     90272854             No       Male      33      canada
# 8     90272858             No       Male      40      Canada
#
#   Q5: STATE, PROVINCE, COUNTY, ETC Q6 | 100 Grand Bar  \
# 3                               or                MEH
# 4                         exton pa                JOY
# 5                                0                JOY
# 7                          ontario                JOY
# 8                          Ontario                JOY
#
#   Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)  \
# 3                                            DESPAIR
# 4                                            DESPAIR
# 5                                            DESPAIR
# ...
